# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Opening

# %%
trend_electric_vehicle = pd.read_csv('multiTimeline electric vehicle trending.csv', header=1)
trend_electric_vehicle['Minggu'] = pd.to_datetime(trend_electric_vehicle['Minggu'], format='%Y-%m-%d')
trend_electric_vehicle
# Out:
#         Minggu  electric vehicle: (Seluruh dunia)
# 0   2017-10-15                                 24
# 1   2017-10-22                                 24
# 2   2017-10-29                                 22
# 3   2017-11-05                                 23
# 4   2017-11-12                                 25
# ..         ...                                ...
# 255 2022-09-04                                 65
# 256 2022-09-11                                 69
# 257 2022-09-18                                 63
# 258 2022-09-25                                 65
# 259 2022-10-02                                 62
#
# [260 rows x 2 columns]

# %%
trend_electric_vehicle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 2 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Minggu                             260 non-null    datetime64[ns]
#  1   electric vehicle: (Seluruh dunia)  260 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 4.2 KB

# %%
data = trend_electric_vehicle
sns.lineplot(data=data, x=data.columns[0], y=data.columns[1])
plt.show()

# %%
data
# Out:
#         Minggu  electric vehicle: (Seluruh dunia)
# 0   2017-10-15                                 24
# 1   2017-10-22                                 24
# 2   2017-10-29                                 22
# 3   2017-11-05                                 23
# 4   2017-11-12                                 25
# ..         ...                                ...
# 255 2022-09-04                                 65
# 256 2022-09-11                                 69
# 257 2022-09-18                                 63
# 258 2022-09-25                                 65
# 259 2022-10-02                                 62
#
# [260 rows x 2 columns]

# %%
data.iloc[:,1]
# Out:
# 0      24
# 1      24
# 2      22
# 3      23
# 4      25
#        ..
# 255    65
# 256    69
# 257    63
# 258    65
# 259    62
# Name: electric vehicle: (Seluruh dunia), Length: 260, dtype: int64

# %% [markdown]
# # Sumber Energi

# %%
elec_source = pd.read_csv('share-elec-by-source.csv')
# elec_source['Year'] = pd.DatetimeIndex(elec_source['Year']).year

elec_source
# Out:
#            Entity Code  Year  Coal (% electricity)  Gas (% electricity)  \
# 0     Afghanistan  AFG  2000              0.000000                  0.0
# 1     Afghanistan  AFG  2001              0.000000                  0.0
# 2     Afghanistan  AFG  2002              0.000000                  0.0
# 3     Afghanistan  AFG  2003              0.000000                  0.0
# 4     Afghanistan  AFG  2004              0.000000                  0.0
# ...           ...  ...   ...                   ...                  ...
# 7063     Zimbabwe  ZWE  2016             50.733135                  0.0
# 7064     Zimbabwe  ZWE  2017             41.313271                  0.0
# 7065     Zimbabwe  ZWE  2018             40.416210                  0.0
# 7066     Zimbabwe  ZWE  2019             32.007072                  0.0
# 7067     Zimbabwe  ZWE  2020             30.963097                  0.0
#
#       Hydro (% electricity)  Solar (% electricity)  Wind (% electricity)  \
# ...

# %%
len(tuple(set(elec_source.Entity))), len(set(elec_source.Entity))
# Out:
# (251, 251)

# %%
elec_source.columns[3:]
# Out:
# Index(['Coal (% electricity)', 'Gas (% electricity)', 'Hydro (% electricity)',
#        'Solar (% electricity)', 'Wind (% electricity)', 'Oil (% electricity)',
#        'Nuclear (% electricity)',
#        'Other renewables including bioenergy (% electricity)'],
#       dtype='object')

# %%
pd.to_datetime(elec_source['Year'], format='%Y').dt.to_period('Y')
# Out:
# 0       2000
# 1       2001
# 2       2002
# 3       2003
# 4       2004
#         ...
# 7063    2016
# 7064    2017
# 7065    2018
# 7066    2019
# 7067    2020
# Name: Year, Length: 7068, dtype: period[A-DEC]

# %%
elec_source['Year'] = pd.to_datetime(elec_source['Year'], format='%Y').dt.to_period('Y')

# %%
elec_source
# Out:
#            Entity Code  Year  Coal (% electricity)  Gas (% electricity)  \
# 0     Afghanistan  AFG  2000              0.000000                  0.0
# 1     Afghanistan  AFG  2001              0.000000                  0.0
# 2     Afghanistan  AFG  2002              0.000000                  0.0
# 3     Afghanistan  AFG  2003              0.000000                  0.0
# 4     Afghanistan  AFG  2004              0.000000                  0.0
# ...           ...  ...   ...                   ...                  ...
# 7063     Zimbabwe  ZWE  2016             50.733135                  0.0
# 7064     Zimbabwe  ZWE  2017             41.313271                  0.0
# 7065     Zimbabwe  ZWE  2018             40.416210                  0.0
# 7066     Zimbabwe  ZWE  2019             32.007072                  0.0
# 7067     Zimbabwe  ZWE  2020             30.963097                  0.0
#
#       Hydro (% electricity)  Solar (% electricity)  Wind (% electricity)  \
# ...

# %%
chart_data = elec_source[(elec_source.Entity == 'World')][elec_source.columns[2:]]
chart_data = chart_data.rename(columns={'Year':'index'}).set_index('index')
chart_data
# Out:
#        Coal (% electricity)  Gas (% electricity)  Hydro (% electricity)  \
# index
# 1985              37.926273            14.431670              20.031889
# 1986              37.717766            14.076060              19.714939
# 1987              38.038494            14.215455              19.064466
# 1988              37.712528            13.835014              18.844994
# 1989              37.545460            14.828184              17.910263
# 1990              37.287308            14.962957              18.048061
# 1991              37.278732            14.851546              18.073460
# 1992              37.682701            14.829936              17.902708
# 1993              37.498951            14.793038              18.583853
# 1994              37.839531            14.896025              18.231459
# 1995              37.641575            15.221087              18.559181
# 1996              38.254063            15.226993              18.243137
# ...

# %%
import re

# %%
elec_source.columns[3:]
# Out:
# Index(['Coal (% electricity)', 'Gas (% electricity)', 'Hydro (% electricity)',
#        'Solar (% electricity)', 'Wind (% electricity)', 'Oil (% electricity)',
#        'Nuclear (% electricity)',
#        'Other renewables including bioenergy (% electricity)'],
#       dtype='object')

# %%
list_x = []
for text in elec_source.columns[3:]:
    x = re.search("[^\s]+",text)
    list_x.append(x[0])
list_x
# Out:
# ['Coal', 'Gas', 'Hydro', 'Solar', 'Wind', 'Oil', 'Nuclear', 'Other']

# %%
dict(zip(elec_source.columns[3:], list_x))
# Out:
# {'Coal (% electricity)': 'Coal',
#  'Gas (% electricity)': 'Gas',
#  'Hydro (% electricity)': 'Hydro',
#  'Solar (% electricity)': 'Solar',
#  'Wind (% electricity)': 'Wind',
#  'Oil (% electricity)': 'Oil',
#  'Nuclear (% electricity)': 'Nuclear',
#  'Other renewables including bioenergy (% electricity)': 'Other'}

# %%
per_capita_energyGroup = pd.read_csv('per-capita-electricity-fossil-nuclear-renewables.csv')
per_capita_energyGroup
# Out:
#            Entity Code  Year  Fossil fuel electricity per capita (kWh)  \
# 0     Afghanistan  AFG  2000                                  8.187080
# 1     Afghanistan  AFG  2001                                  4.571166
# 2     Afghanistan  AFG  2002                                  6.190400
# 3     Afghanistan  AFG  2003                                 13.689474
# 4     Afghanistan  AFG  2004                                 14.010625
# ...           ...  ...   ...                                       ...
# 6215     Zimbabwe  ZWE  2016                                242.169205
# 6216     Zimbabwe  ZWE  2017                                206.764221
# 6217     Zimbabwe  ZWE  2018                                247.804459
# 6218     Zimbabwe  ZWE  2019                                238.364960
# 6219     Zimbabwe  ZWE  2020                                222.085190
#
#       Nuclear electricity per capita (kWh)  \
# 0                                      0.0
# ...

# %%
list_energy_group = []
for text in per_capita_energyGroup.columns[3:]:
    list_energy_group.append(text.split()[0])
list_energy_group
# Out:
# ['Fossil', 'Nuclear', 'Renewable']

# %%
prod_source = pd.read_csv('electricity-prod-source-stacked.csv')
prod_source
# Out:
#            Entity Code  Year  Other renewables including bioenergy (TWh)  \
# 0     Afghanistan  AFG  2000                                        0.00
# 1     Afghanistan  AFG  2001                                        0.00
# 2     Afghanistan  AFG  2002                                        0.00
# 3     Afghanistan  AFG  2003                                        0.00
# 4     Afghanistan  AFG  2004                                        0.00
# ...           ...  ...   ...                                         ...
# 9170     Zimbabwe  ZWE  2016                                        0.36
# 9171     Zimbabwe  ZWE  2017                                        0.32
# 9172     Zimbabwe  ZWE  2018                                        0.39
# 9173     Zimbabwe  ZWE  2019                                        0.38
# 9174     Zimbabwe  ZWE  2020                                        0.36
#
#       Electricity from solar (TWh)  Electricity from wind (TWh)  \
# ...

# %%
carbon = pd.read_csv('carbon-intensity-electricity.csv')
carbon
# Out:
#            Entity Code  Year  Carbon intensity of electricity (gCO2/kWh)
# 0     Afghanistan  AFG  2000                                  255.319138
# 1     Afghanistan  AFG  2001                                  118.644066
# 2     Afghanistan  AFG  2002                                  144.927536
# 3     Afghanistan  AFG  2003                                  255.319138
# 4     Afghanistan  AFG  2004                                  269.662903
# ...           ...  ...   ...                                         ...
# 4829     Zimbabwe  ZWE  2016                                  442.815247
# 4830     Zimbabwe  ZWE  2017                                  363.885101
# 4831     Zimbabwe  ZWE  2018                                  358.159882
# 4832     Zimbabwe  ZWE  2019                                  288.240479
# 4833     Zimbabwe  ZWE  2020                                  279.027893
#
# [4834 rows x 4 columns]

# %%
df_merge = pd.merge(left=prod_source, right=carbon, on=['Entity','Code','Year'], how='right')
df_merge
# Out:
#            Entity Code  Year  Other renewables including bioenergy (TWh)  \
# 0     Afghanistan  AFG  2000                                        0.00
# 1     Afghanistan  AFG  2001                                        0.00
# 2     Afghanistan  AFG  2002                                        0.00
# 3     Afghanistan  AFG  2003                                        0.00
# 4     Afghanistan  AFG  2004                                        0.00
# ...           ...  ...   ...                                         ...
# 4829     Zimbabwe  ZWE  2016                                        0.36
# 4830     Zimbabwe  ZWE  2017                                        0.32
# 4831     Zimbabwe  ZWE  2018                                        0.39
# 4832     Zimbabwe  ZWE  2019                                        0.38
# 4833     Zimbabwe  ZWE  2020                                        0.36
#
#       Electricity from solar (TWh)  Electricity from wind (TWh)  \
# ...

# %%
data = df_merge[df_merge.Entity == 'Norway']
data.columns
# Out:
# Index(['Entity', 'Code', 'Year', 'Other renewables including bioenergy (TWh)',
#        'Electricity from solar (TWh)', 'Electricity from wind (TWh)',
#        'Electricity from hydro (TWh)', 'Electricity from nuclear (TWh)',
#        'Electricity from oil (TWh)', 'Electricity from gas (TWh)',
#        'Electricity from coal (TWh)',
#        'Carbon intensity of electricity (gCO2/kWh)'],
#       dtype='object')

# %%
for i in range(3, len(data.columns)-1):
    sns.scatterplot(data=data, x=data.columns[i], 
                    y='Carbon intensity of electricity (gCO2/kWh)')
    plt.show()

# %% [markdown]
# # Cek Trend

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
# Elec source
data = elec_source[elec_source.Entity == 'World'][['Year',elec_source.columns[4]]]
data
ax = sns.lineplot(x=data['Year'].astype('str'), y=data[data.columns[1]])
ax.tick_params(axis='x', labelrotation=90)
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37 entries, 6968 to 7004
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 37 non-null     period[A-DEC]
#  1   Gas (% electricity)  37 non-null     float64
# dtypes: float64(1), period[A-DEC](1)
# memory usage: 888.0 bytes

# %%
data['Year'] = pd.to_datetime(data['Year'].astype('str'))
data.set_index('Year',inplace=True)

# %%
# seasonal_decompose(data, model='multiplicative').plot()
seasonal_decompose(data, period=2).plot()
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

# %%
adfuller(data)
# Out:
# (-0.6864447723130992,
#  0.8502294740609568,
#  0,
#  36,
#  {'1%': -3.626651907578875,
#   '5%': -2.9459512825788754,
#   '10%': -2.6116707716049383},
#  37.176835234629884)

# %%
from scipy.misc import derivative

# %%
elec_source.shape, prod_source.shape
# Out:
# ((7068, 11), (9175, 11))

# %%
elec_source['Year'] = elec_source['Year'].astype('str')
elec_source['Year'] = elec_source['Year'].astype('int64')
elec_source.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7068 entries, 0 to 7067
# Data columns (total 11 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Entity                                                7068 non-null   object
#  1   Code                                                  5715 non-null   object
#  2   Year                                                  7068 non-null   int64
#  3   Coal (% electricity)                                  6387 non-null   float64
#  4   Gas (% electricity)                                   6388 non-null   float64
#  5   Hydro (% electricity)                                 7063 non-null   float64
#  6   Solar (% electricity)                                 7008 non-null   float64
#  7   Wind (% electricity)                                  7007 non-null   float64
# ...

# %%
prod_source.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9175 entries, 0 to 9174
# Data columns (total 11 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Entity                                      9175 non-null   object
#  1   Code                                        7182 non-null   object
#  2   Year                                        9175 non-null   int64
#  3   Other renewables including bioenergy (TWh)  8899 non-null   float64
#  4   Electricity from solar (TWh)                8939 non-null   float64
#  5   Electricity from wind (TWh)                 8953 non-null   float64
#  6   Electricity from hydro (TWh)                9170 non-null   float64
#  7   Electricity from nuclear (TWh)              8808 non-null   float64
#  8   Electricity from oil (TWh)                  6438 non-null   float64
# ...

# %%
df_merge = pd.merge(left=prod_source, right=elec_source, on=['Entity','Code','Year'], how='right')
df_merge
# Out:
#            Entity Code  Year  Other renewables including bioenergy (TWh)  \
# 0     Afghanistan  AFG  2000                                        0.00
# 1     Afghanistan  AFG  2001                                        0.00
# 2     Afghanistan  AFG  2002                                        0.00
# 3     Afghanistan  AFG  2003                                        0.00
# 4     Afghanistan  AFG  2004                                        0.00
# ...           ...  ...   ...                                         ...
# 7063     Zimbabwe  ZWE  2016                                        0.36
# 7064     Zimbabwe  ZWE  2017                                        0.32
# 7065     Zimbabwe  ZWE  2018                                        0.39
# 7066     Zimbabwe  ZWE  2019                                        0.38
# 7067     Zimbabwe  ZWE  2020                                        0.36
#
#       Electricity from solar (TWh)  Electricity from wind (TWh)  \
# ...

# %%
energy = list_x[0].lower()
list_check = []
for text in df_merge.columns:
    check = text.lower().find(energy)
    if check != -1:
        list_check.append(text)

# %%
data = df_merge[list_check][df_merge.Entity == 'World']
sns.lineplot(data=data, x=data.columns[0], y=data.columns[1])
# Out:
# <AxesSubplot:xlabel='Electricity from coal (TWh)', ylabel='Coal (% electricity)'>

# %% [markdown]
# # Find trend

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px

# %%
prod_source.Entity.unique()
# Out:
# array(['Afghanistan', 'Africa', 'Africa (BP)', 'Albania', 'Algeria',
#        'American Samoa', 'Angola', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Asia', 'Asia Pacific (BP)', 'Australia',
#        'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh',
#        'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda',
#        'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana',
#        'Brazil', 'British Virgin Islands', 'Brunei', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'CIS (BP)', 'Cambodia', 'Cameroon',
#        'Canada', 'Cape Verde', 'Cayman Islands',
#        'Central African Republic', 'Central America (BP)', 'Chad',
#        'Chile', 'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Cyprus',
#        'Czechia', 'Democratic Republic of Congo', 'Denmark', 'Djibouti',
#        'Dominica', 'Dominican Republic', 'Eastern Africa (BP)', 'Ecuador',
# ...

# %%
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces
fig.add_trace(
    go.Scatter(x=[1, 2, 3], y=[40, 50, 60], name="yaxis data"),
    secondary_y=False,
)

fig.add_trace(
    go.Scatter(x=[2, 3, 4], y=[4, 5, 6], name="yaxis2 data"),
    secondary_y=True,
)

# Add figure title
fig.update_layout(
    title_text="Double Y Axis Example"
)

# Set x-axis title
fig.update_xaxes(title_text="xaxis title")

# Set y-axes titles
fig.update_yaxes(title_text="<b>primary</b> yaxis title", secondary_y=False)
fig.update_yaxes(title_text="<b>secondary</b> yaxis title", secondary_y=True)

fig.show()

# %% [markdown]
# ## TWh, CO2, time series

# %%
df_source_carbon = pd.merge(left=prod_source, right=carbon, on=['Entity','Code','Year'], how='right')
df_source_carbon
# Out:
#            Entity Code  Year  Other renewables including bioenergy (TWh)  \
# 0     Afghanistan  AFG  2000                                        0.00
# 1     Afghanistan  AFG  2001                                        0.00
# 2     Afghanistan  AFG  2002                                        0.00
# 3     Afghanistan  AFG  2003                                        0.00
# 4     Afghanistan  AFG  2004                                        0.00
# ...           ...  ...   ...                                         ...
# 4829     Zimbabwe  ZWE  2016                                        0.36
# 4830     Zimbabwe  ZWE  2017                                        0.32
# 4831     Zimbabwe  ZWE  2018                                        0.39
# 4832     Zimbabwe  ZWE  2019                                        0.38
# 4833     Zimbabwe  ZWE  2020                                        0.36
#
#       Electricity from solar (TWh)  Electricity from wind (TWh)  \
# ...

# %%
cols = df_source_carbon.columns
data = df_source_carbon[df_source_carbon.Entity == 'Europe']

# Add traces
for col in cols[3:-1]:
    fig = make_subplots(specs=[[{"secondary_y": True}]])
    fig.add_trace(
        go.Scatter(x=data['Year'], y=data[col], name=col),
        secondary_y=False,
    )

    fig.add_trace(
        go.Scatter(x=data['Year'], y=data[cols[-1]], name=cols[-1]),
        secondary_y=True,
    )

    # Add figure title
    fig.update_layout(
        title_text="Double Y Axis Example"
    )

    # Set x-axis title
    fig.update_xaxes(title_text="xaxis title")

    # Set y-axes titles
    fig.update_yaxes(title_text="<b>primary</b> yaxis title", secondary_y=False)
    fig.update_yaxes(title_text="<b>secondary</b> yaxis title", secondary_y=True)

    fig.show()

# %%
from scipy.interpolate import interp1d
from scipy.misc import derivative

# %%
def plot_trend(data, column, spacing):
    
    x=data['Year']
    y=data[column]

    f = interp1d(x=data['Year'], y=data[column])
    x_fake = np.arange(data['Year'].min()+spacing, data['Year'].max()-spacing,spacing)
    df_dx = derivative(f, x_fake, dx=1e-6)

    # Plot
    fig = plt.figure()
    ax1 = fig.add_subplot(211)
    ax2 = fig.add_subplot(212)

    ax1.errorbar(x, y, fmt="o", color="blue", label='Input data')
    ax1.errorbar(x_fake, f(x_fake), label="Interpolated data", lw=2)
    ax1.set_xlabel("x")
    ax1.set_ylabel("y")

    ax2.errorbar(x_fake, df_dx, fmt='-o', lw=2)
    ax2.errorbar(x_fake, np.array([0 for i in x_fake]), ls="--", lw=2)
    ax2.set_xlabel("x")
    ax2.set_ylabel("dy/dx")

    leg = ax1.legend(loc=2, numpoints=1,scatterpoints=1)
    leg.draw_frame(False)
    
    average = np.average(df_dx)

    print(f'trend of {column}')
    if average > 0 :
        print("Uptrend")
    elif average < 0:
        print("Downtrend")
    elif average == 0:
        print("No trend!")
    
    print('Average trend measure is:')
    print(average)
    print("Max trend measure is:")
    print(np.max(df_dx))
    print("min trend measure is:")
    print(np.min(df_dx))
    
    return x_fake, df_dx, average

# %%
cols = df_source_carbon.columns
data = df_source_carbon[df_source_carbon.Entity == 'Europe']
col = cols[-1]

x_fake, df_dx, average = plot_trend(data, column=col, spacing=0.5)
# Out:
# trend of Carbon intensity of electricity (gCO2/kWh)
# Downtrend
# Average trend measure is:
# -5.201885803529649
# Max trend measure is:
# 6.231079794360994
# min trend measure is:
# -21.277132503882967

# %%
cols = elec_source.columns
data = elec_source[elec_source.Entity == 'Europe']
list_source = []
list_average = []

for col in cols[3:]:
    x_fake, df_dx, average = plot_trend(data, column=col, spacing=0.5)
    list_source.append(col)
    list_average.append(average)
# Out:
# trend of Coal (% electricity)
# Downtrend
# Average trend measure is:
# -0.5405683030978992
# Max trend measure is:
# 0.9338818642845581
# min trend measure is:
# -2.928242055943997
# trend of Gas (% electricity)
# Uptrend
# Average trend measure is:
# 0.19976096330103538
# Max trend measure is:
# 1.9675657547679748
# min trend measure is:
# -2.574837017377263
# trend of Hydro (% electricity)
# Uptrend
# Average trend measure is:
# 0.0012406213072730615
# Max trend measure is:
# 1.7271215444480958
# min trend measure is:
# -1.775212485455313
# trend of Solar (% electricity)
# Uptrend
# Average trend measure is:
# 0.10310499607870552
# Max trend measure is:
# 0.6139245716241248
# min trend measure is:
# -0.00018667431749691543
# trend of Wind (% electricity)
# Uptrend
# Average trend measure is:
# 0.2923972954751835
# Max trend measure is:
# 1.3807450880420902
# min trend measure is:
# -0.06249762307675155
# trend of Oil (% electricity)
# Downtrend
# Average trend measure is:
# ...

# %%
pd.DataFrame({'source':list_source, 'average_trend':list_average})
# Out:
#                                               source  average_trend
# 0                               Coal (% electricity)      -0.540568
# 1                                Gas (% electricity)       0.199761
# 2                              Hydro (% electricity)       0.001241
# 3                              Solar (% electricity)       0.103105
# 4                               Wind (% electricity)       0.292397
# 5                                Oil (% electricity)      -0.244898
# 6                            Nuclear (% electricity)       0.044909
# 7  Other renewables including bioenergy (% electr...       0.124656

# %%
cols = df_source_carbon.columns
data = df_source_carbon[df_source_carbon.Entity == 'Europe']
list_source = []
list_average = []

for col in cols[3:]:
    x_fake, df_dx, average = plot_trend(data, column=col, spacing=0.5)
    list_source.append(col)
    list_average.append(average)
# Out:
# trend of Other renewables including bioenergy (TWh)
# Uptrend
# Average trend measure is:
# 9.010173941970123
# Max trend measure is:
# 16.303026114883323
# min trend measure is:
# 2.744842845459061
# trend of Electricity from solar (TWh)
# Uptrend
# Average trend measure is:
# 8.563736095608744
# Max trend measure is:
# 25.130011493956772
# min trend measure is:
# 0.11972926397540995
# trend of Electricity from wind (TWh)
# Uptrend
# Average trend measure is:
# 23.10298442322889
# Max trend measure is:
# 59.00180707385516
# min trend measure is:
# 0.0857239115248376
# trend of Electricity from hydro (TWh)
# Uptrend
# Average trend measure is:
# 2.151632938307557
# Max trend measure is:
# 65.51453361680615
# min trend measure is:
# -84.12928184498014
# trend of Electricity from nuclear (TWh)
# Downtrend
# Average trend measure is:
# -6.227260504942933
# Max trend measure is:
# 39.405155803251546
# min trend measure is:
# -89.49415064307686
# trend of Electricity from oil (TWh)
# ...

# %%
pd.DataFrame({'source':list_source, 'average_trend':list_average})
# Out:
#                                        source  average_trend
# 0  Other renewables including bioenergy (TWh)       9.010174
# 1                Electricity from solar (TWh)       8.563736
# 2                 Electricity from wind (TWh)      23.102984
# 3                Electricity from hydro (TWh)       2.151633
# 4              Electricity from nuclear (TWh)      -6.227261
# 5                  Electricity from oil (TWh)      -7.904504
# 6                  Electricity from gas (TWh)      13.936132
# 7                 Electricity from coal (TWh)     -27.487337
# 8  Carbon intensity of electricity (gCO2/kWh)      -5.201886

# %%
pd.DataFrame(data[data.columns[3:-1]].mean(), columns=['average']).sort_values(ascending=False, by='average')
# Out:
#                                                 average
# Electricity from nuclear (TWh)              1185.195107
# Electricity from gas (TWh)                  1127.436809
# Electricity from coal (TWh)                 1101.641413
# Electricity from hydro (TWh)                 735.339980
# Electricity from wind (TWh)                  205.162146
# Other renewables including bioenergy (TWh)   137.865875
# Electricity from oil (TWh)                   120.772104
# Electricity from solar (TWh)                  60.127253

# %%
cols = elec_source.columns
data = elec_source[elec_source.Entity == 'World']
pd.DataFrame(data[data.columns[3:]].mean(), columns=['average']).sort_values(ascending=False, by='average')
# Out:
#                                                       average
# Coal (% electricity)                                38.508370
# Gas (% electricity)                                 19.005810
# Hydro (% electricity)                               16.928686
# Nuclear (% electricity)                             14.353963
# Oil (% electricity)                                  7.118279
# Other renewables including bioenergy (% electri...   1.501374
# Wind (% electricity)                                 1.423215
# Solar (% electricity)                                0.494762

# %%
x=data['Year']
y=data[cols[-1]]

f = interp1d(x, y)
x_fake = np.arange(x.min()+1/12, x.max()-1/12,1/12)
df_dx = derivative(f, x_fake, dx=1e-6)

# Plot
fig = plt.figure()
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

ax1.errorbar(x, y, fmt="o", color="blue", label='Input data')
ax1.errorbar(x_fake, f(x_fake), label="Interpolated data", lw=2)
ax1.set_xlabel("x")
ax1.set_ylabel("y")

ax2.errorbar(x_fake, df_dx, fmt='-o', lw=2)
ax2.errorbar(x_fake, np.array([0 for i in x_fake]), ls="--", lw=2)
ax2.set_xlabel("x")
ax2.set_ylabel("dy/dx")

leg = ax1.legend(loc=2, numpoints=1,scatterpoints=1)
leg.draw_frame(False)

# %%
px.line(x=x_fake, y=df_dx, markers=True)

# %%
data_df_dx = pd.DataFrame({'x':x_fake, 'df_dx':df_dx})
data_df_dx['df_dx'] = np.abs(data_df_dx['df_dx'])
near_zero = data_df_dx.sort_values(by='df_dx').head(10)
near_zero
# Out:
#                x     df_dx
# 119  1995.000000  0.001940
# 23   1987.000000  0.002620
# 122  1995.250000  0.003453
# 123  1995.333333  0.003453
# 127  1995.666667  0.003453
# 128  1995.750000  0.003453
# 125  1995.500000  0.003453
# 120  1995.083333  0.003453
# 121  1995.166667  0.003453
# 130  1995.916667  0.003453

# %%
gd_near_zero = [] 
for year in near_zero.x:
    if year%1 >= 0.99:
        year = np.around(year)
    # print(re.findall(r"\d{4}",str(year))[0])
    gd_near_zero.append(re.findall(r"\d{4}",str(year))[0])
gd_near_zero = list(set(gd_near_zero))
gd_near_zero
# Out:
# ['1987', '1995']

# %%
data_df_dx = pd.DataFrame({'x':x_fake, 'df_dx':df_dx})
data_after_nearzero = data_df_dx[data_df_dx.x >= int(gd_near_zero[0])-0.0000001]
average = np.average(data_after_nearzero.df_dx)
average
# Out:
# 0.05340431138610843

# %%
data_df_dx = pd.DataFrame({'x':x_fake, 'df_dx':df_dx})
data_after_nearzero = data_df_dx[data_df_dx.x >= int(gd_near_zero[1])-0.0000001]
average = np.average(data_after_nearzero.df_dx)
average
# Out:
# 0.060836336759550455

# %%
data = df_source_carbon[df_source_carbon.Entity == 'Europe']
gd_max_neg = data[data.Year == 2011]
gd_max_neg
# Out:
#       Entity Code  Year  Other renewables including bioenergy (TWh)  \
# 1382  Europe  NaN  2011                                  145.835663
#
#       Electricity from solar (TWh)  Electricity from wind (TWh)  \
# 1382                     47.103886                   181.942886
#
#       Electricity from hydro (TWh)  Electricity from nuclear (TWh)  \
# 1382                    680.404114                     1197.106934
#
#       Electricity from oil (TWh)  Electricity from gas (TWh)  \
# 1382                  104.252281                  1248.43042
#
#       Electricity from coal (TWh)  Carbon intensity of electricity (gCO2/kWh)
# 1382                  1161.185791                                  352.762665

# %% [markdown]
# # Group Fossiel, Renewable energy (include nuclear)

# %%
list_source = []
for text in elec_source.columns[3:]:
    x = re.search("[^\s]+",text)
    list_source.append(x[0])
list_source
# Out:
# ['Coal', 'Gas', 'Hydro', 'Solar', 'Wind', 'Oil', 'Nuclear', 'Other']

# %%
list_fossil = ['Coal', 'Gas', 'Oil']
list_renewable = [source for source in list_source if source not in list_fossil]
list_renewable
# Out:
# ['Hydro', 'Solar', 'Wind', 'Nuclear', 'Other']

# %%
elec_source
# Out:
#            Entity Code  Year  Coal (% electricity)  Gas (% electricity)  \
# 0     Afghanistan  AFG  2000              0.000000                  0.0
# 1     Afghanistan  AFG  2001              0.000000                  0.0
# 2     Afghanistan  AFG  2002              0.000000                  0.0
# 3     Afghanistan  AFG  2003              0.000000                  0.0
# 4     Afghanistan  AFG  2004              0.000000                  0.0
# ...           ...  ...   ...                   ...                  ...
# 7063     Zimbabwe  ZWE  2016             50.733135                  0.0
# 7064     Zimbabwe  ZWE  2017             41.313271                  0.0
# 7065     Zimbabwe  ZWE  2018             40.416210                  0.0
# 7066     Zimbabwe  ZWE  2019             32.007072                  0.0
# 7067     Zimbabwe  ZWE  2020             30.963097                  0.0
#
#       Hydro (% electricity)  Solar (% electricity)  Wind (% electricity)  \
# ...

# %%
list_fossil_fullname = []
list_renewable_fullname = []
for fossil in list_fossil:
    for col in elec_source.columns[3:]:
        if fossil in col:
            list_fossil_fullname.append(col)
            break

for renewable in list_renewable:
    for col in elec_source.columns[3:]:
        if renewable in col:
            list_renewable_fullname.append(col)
            break

# %%
list_renewable_fullname, list_fossil_fullname
# Out:
# (['Hydro (% electricity)',
#   'Solar (% electricity)',
#   'Wind (% electricity)',
#   'Nuclear (% electricity)',
#   'Other renewables including bioenergy (% electricity)'],
#  ['Coal (% electricity)', 'Gas (% electricity)', 'Oil (% electricity)'])

# %%
elec_source['Fossil (% electricity)'] = elec_source[list_fossil_fullname].sum(axis=1)
elec_source['Renewable (% electricity)'] = elec_source[list_renewable_fullname].sum(axis=1)

# %%
new_cols = ['Fossil (% electricity)', 'Renewable (% electricity)']
first_cols = list(elec_source.columns[:3])
first_cols.extend(new_cols)
first_cols
# Out:
# ['Entity',
#  'Code',
#  'Year',
#  'Fossil (% electricity)',
#  'Renewable (% electricity)']

# %%
elec_source[first_cols] #[elec_source.Entity == 'World']
# Out:
#            Entity Code  Year  Fossil (% electricity)  \
# 0     Afghanistan  AFG  2000               34.042553
# 1     Afghanistan  AFG  2001               15.254238
# 2     Afghanistan  AFG  2002               18.840580
# 3     Afghanistan  AFG  2003               32.978722
# 4     Afghanistan  AFG  2004               37.078651
# ...           ...  ...   ...                     ...
# 7063     Zimbabwe  ZWE  2016               51.319645
# 7064     Zimbabwe  ZWE  2017               41.723667
# 7065     Zimbabwe  ZWE  2018               40.854326
# 7066     Zimbabwe  ZWE  2019               32.360742
# 7067     Zimbabwe  ZWE  2020               31.323133
#
#       Renewable (% electricity)
# 0                     65.957443
# 1                     84.745766
# 2                     81.159424
# 3                     67.021278
# 4                     62.921349
# ...                         ...
# 7063                  48.680350
# 7064                  58.276334
# ...

# %%
first_cols[-2:]
# Out:
# ['Fossil (% electricity)', 'Renewable (% electricity)']

# %%
cols = first_cols[-2:]
data = elec_source[elec_source.Entity == 'Indonesia']
list_source = []
list_average = []

for col in cols:
    x_fake, df_dx, average = plot_trend(data, column=col, spacing=0.5)
    list_source.append(col)
    list_average.append(average)
# Out:
# trend of Fossil (% electricity)
# Uptrend
# Average trend measure is:
# 0.01595712808872512
# Max trend measure is:
# 6.813628957047513
# min trend measure is:
# -7.289795732390303
# trend of Renewable (% electricity)
# Downtrend
# Average trend measure is:
# -0.016745540573229585
# Max trend measure is:
# 7.289786196906789
# min trend measure is:
# -6.812914175924334

# %%
cols = df_source_carbon.columns
data = df_source_carbon[df_source_carbon.Entity == 'Indonesia']
list_source = []
list_average = []

for col in [cols[-1]]:
    x_fake, df_dx, average = plot_trend(data, column=col, spacing=0.5)
    list_source.append(col)
    list_average.append(average)
# Out:
# trend of Carbon intensity of electricity (gCO2/kWh)
# Uptrend
# Average trend measure is:
# 2.705627737572956
# Max trend measure is:
# 32.63916380547016
# min trend measure is:
# -30.343326102411083

# %%
elec_source.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7068 entries, 0 to 7067
# Data columns (total 13 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Entity                                                7068 non-null   object
#  1   Code                                                  5715 non-null   object
#  2   Year                                                  7068 non-null   int64
#  3   Coal (% electricity)                                  6387 non-null   float64
#  4   Gas (% electricity)                                   6388 non-null   float64
#  5   Hydro (% electricity)                                 7063 non-null   float64
#  6   Solar (% electricity)                                 7008 non-null   float64
#  7   Wind (% electricity)                                  7007 non-null   float64
# ...

# %%
elec_source.shape, carbon.shape
# Out:
# ((7068, 13), (4834, 4))

# %%
len(elec_source.Entity.unique()),len(carbon.Entity.unique())
# Out:
# (251, 228)

# %%
[entity for entity in elec_source.Entity.unique() if entity not in carbon.Entity.unique()]
# Out:
# ['Africa (BP)',
#  'Asia Pacific (BP)',
#  'CIS (BP)',
#  'Central America (BP)',
#  'Eastern Africa (BP)',
#  'Europe (BP)',
#  'Middle Africa (BP)',
#  'Middle East (BP)',
#  'Non-OECD (BP)',
#  'North America (BP)',
#  'OECD (BP)',
#  'Other Africa (BP)',
#  'Other Asia Pacific (BP)',
#  'Other CIS (BP)',
#  'Other Caribbean (BP)',
#  'Other Europe (BP)',
#  'Other Middle East (BP)',
#  'Other Northern Africa (BP)',
#  'Other South America (BP)',
#  'Other South and Central America (BP)',
#  'Other Southern Africa (BP)',
#  'South and Central America (BP)',
#  'Western Africa (BP)']

# %%
list_fossil = ['Coal', 'Gas', 'Oil']
list_renewable = [source for source in list_source if source not in list_fossil]

list_fossil_fullname = []
list_renewable_fullname = []
for fossil in list_fossil:
    for col in elec_source.columns[3:]:
        if fossil in col:
            list_fossil_fullname.append(col)
            break

for renewable in list_renewable:
    for col in elec_source.columns[3:]:
        if renewable in col:
            list_renewable_fullname.append(col)
            break

elec_source['Fossil (% electricity)'] = elec_source[list_fossil_fullname].sum(axis=1)
elec_source['Renewable (% electricity)'] = elec_source[list_renewable_fullname].sum(axis=1)

carbon = pd.read_csv('carbon-intensity-electricity.csv')

carbon['Year'] = carbon['Year'].astype('str')
carbon['Year'] = carbon['Year'].astype('int64')


new_cols = ['Fossil (% electricity)', 'Renewable (% electricity)']
first_cols = list(elec_source.columns[:3])
first_cols.extend(new_cols)

cols = first_cols[-3:]
data = elec_source
data['Year'] = data['Year'].astype('str')
data['Year'] = data['Year'].astype('int64')
data = pd.merge(left=elec_source, right=carbon, on=['Entity','Code','Year'], how='right')

# %%
def data_trend(data, columns, spacing):

    cols_entity = list(data.Entity.unique())
    
    df_ = pd.DataFrame({'Entity':cols_entity})

    for column in columns:
        cols_trend_value = []
        col_entity_remove = []
        print(column)
        for option in cols_entity:
            # print(option)
            x=data[data.Entity == option]['Year']
            y=data[data.Entity == option][column]
            
            try:
                f = interp1d(x=x, y=y)
            except Exception:
                col_entity_remove.append(option)
                continue
            else:
                x_fake = np.arange(x.min()+spacing, x.max()-spacing,spacing)
                df_dx = derivative(f, x_fake, dx=1e-6)

                average = np.around(np.average(df_dx),4)

                cols_trend_value.append(average)

                df_add = pd.DataFrame({"Trend "+column: cols_trend_value})
                
        df_ = df_[~df_.Entity.isin(col_entity_remove)]
        df_ = pd.concat([df_, df_add], axis=1)
    return df_

data = pd.merge(left=elec_source[first_cols], right=carbon, on=['Entity','Code','Year'], how='right')
columns = data.columns[-3:]
print(columns)
df_ = data_trend(data=data, columns=columns, spacing=0.5)
df_
# Out:
# Index(['Fossil (% electricity)', 'Renewable (% electricity)',
#        'Carbon intensity of electricity (gCO2/kWh)'],
#       dtype='object')
# Fossil (% electricity)
# Renewable (% electricity)
# Carbon intensity of electricity (gCO2/kWh)
#              Entity  Trend Fossil (% electricity)  \
# 0       Afghanistan                       -0.6718
# 1            Africa                       -0.1726
# 2           Albania                       -0.2089
# 3           Algeria                       -0.0670
# 4    American Samoa                        0.0000
# ..              ...                           ...
# 224           World                       -0.7762
# 225           Yemen                        0.6229
# 226          Zambia                       -0.9948
# 227        Zimbabwe                           NaN
# 203             NaN                        1.9846
#
#      Trend Renewable (% electricity)  \
# 0                                0.0
# 1                                0.0
# ...

# %%
data = pd.merge(left=elec_source[first_cols], right=carbon, on=['Entity','Code','Year'], how='right')
cols_entity = list(data.Entity.unique())
columns = data.columns[-3:]

dict_trend = {'Entity':cols_entity}
for col in columns:
    cols_trend_value = []
    for option in cols_entity:
        x=data[data.Entity == option]['Year']
        y=data[data.Entity == option][col]

        try:
            f = interp1d(x=x, y=y)
        except Exception:
            cols_trend_value.append(np.nan)
        else:
            spacing = 0.5
            x_fake = np.arange(x.min()+spacing, x.max()-spacing,spacing)
            df_dx = derivative(f, x_fake, dx=1e-6)

            average = np.around(np.average(df_dx),4)

            cols_trend_value.append(average)
    
    dict_trend['Trend '+col] = cols_trend_value

# %% [markdown]
# # Rate and Trend

# %%
lnd_agri = pd.read_csv('API_AG.LND.AGRI.ZS_DS2_en_csv_v2_4645905.csv', header=2)
lnd_agri.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021',
#        'Unnamed: 66'],
#       dtype='object')

# %%
lnd_agri
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                          Indicator Name  Indicator Code  1960       1961  \
# 0    Agricultural land (% of land area)  AG.LND.AGRI.ZS   NaN  11.111111
# 1    Agricultural land (% of land area)  AG.LND.AGRI.ZS   NaN  42.345505
# 2    Agricultural land (% of land area)  AG.LND.AGRI.ZS   NaN  57.801696
# 3    Agricultural land (% of land area)  AG.LND.AGRI.ZS   NaN  32.945755
# ...

# %%
cols = lnd_agri.columns
data = lnd_agri[lnd_agri['Country Name'] == 'Aruba']
data_country = data[cols[4:-1]].T.reset_index()
data_country.columns = ['Year', 'Agricultural land (% of land area)']
data_country
# Out:
#     Year  Agricultural land (% of land area)
# 0   1960                                 NaN
# 1   1961                           11.111111
# 2   1962                           11.111111
# 3   1963                           11.111111
# 4   1964                           11.111111
# ..   ...                                 ...
# 57  2017                           11.111111
# 58  2018                           11.111111
# 59  2019                           11.111111
# 60  2020                           11.111111
# 61  2021                                 NaN
#
# [62 rows x 2 columns]

# %%
data_country['Year'] = data_country['Year'].astype('int')
data_used = data_country[(data_country.Year >= 2000)&(data_country.Year < 2021)]
x = data_used['Year']
y = data_used[data_used.columns[1]]

x.shape, y.shape
# Out:
# ((21,), (21,))

# %%
def average_all_dataworld(lnd_agri):

    countries = lnd_agri['Country Name'].unique()

    dict_ = {}
    list_country, list_code, list_average_rate, list_average_trend_rate = [],[],[],[]

    for country in countries:
        data = lnd_agri[lnd_agri['Country Name'] == country]

        cols = lnd_agri.columns
        
        col_idk = lnd_agri[lnd_agri.columns[2]].iloc[0]

        data_country = data[cols[4:-1]].T.reset_index()
        data_country.columns = ['Year', col_idk]
        data_country

        data_country['Year'] = data_country['Year'].astype('int')
        data_used = data_country[(data_country.Year >= 2000)&(data_country.Year < 2021)]
        x = data_used['Year']
        y = data_used[data_used.columns[1]]

        x.shape, y.shape
        f = interp1d(x=x, y=y)

        cols_trend_value.append(np.nan)

        spacing = 0.5
        x_fake = np.arange(x.min()+spacing, x.max()-spacing,spacing)
        df_dx = derivative(f, x_fake, dx=1e-6)

        average_trend_rate = np.around(np.average(df_dx),4)
        average_rate = np.around(np.average(y),4)

        list_country.append(country)
        list_code.append(data['Country Code'].iloc[0])
        list_average_rate.append(average_rate)
        list_average_trend_rate.append(average_trend_rate)

    col_desc = data_country.columns[1]
    dict_['Entity'] = list_country
    dict_['Code'] = list_code
    dict_[f'Average Rate of {col_desc}'] = list_average_rate 
    dict_[f'Average Rate Trend of {col_desc}'] = list_average_trend_rate

    return pd.DataFrame(dict_)

# %%
average_all_dataworld(lnd_agri)
# Out:
#                           Entity Code  \
# 0                          Aruba  ABW
# 1    Africa Eastern and Southern  AFE
# 2                    Afghanistan  AFG
# 3     Africa Western and Central  AFW
# 4                         Angola  AGO
# ..                           ...  ...
# 261                       Kosovo  XKX
# 262                  Yemen, Rep.  YEM
# 263                 South Africa  ZAF
# 264                       Zambia  ZMB
# 265                     Zimbabwe  ZWE
#
#      Average Rate of Agricultural land (% of land area)  \
# 0                                              11.1111
# 1                                              44.7390
# 2                                              58.1366
# 3                                              38.7831
# 4                                              42.0572
# ..                                                 ...
# 261                                                NaN
# ...

# %%
lnd_agri = pd.read_csv('API_AG.LND.AGRI.ZS_DS2_en_csv_v2_4645905.csv', header=2)
lnd_frst = pd.read_csv('API_AG.LND.FRST.ZS_DS2_en_csv_v2_4666292.csv', header=2)
gdp = pd.read_csv('API_NY.GDP.PCAP.CD_DS2_en_csv_v2_4662356.csv', header=2)

worldbank_data = [lnd_agri, lnd_frst, gdp]

# %%
df_c = pd.DataFrame()
for data in worldbank_data:
    df_result = average_all_dataworld(data)
    df_c = pd.concat([df_c,df_result], axis=1, )
df_c
# Out:
#                           Entity Code  \
# 0                          Aruba  ABW
# 1    Africa Eastern and Southern  AFE
# 2                    Afghanistan  AFG
# 3     Africa Western and Central  AFW
# 4                         Angola  AGO
# ..                           ...  ...
# 261                       Kosovo  XKX
# 262                  Yemen, Rep.  YEM
# 263                 South Africa  ZAF
# 264                       Zambia  ZMB
# 265                     Zimbabwe  ZWE
#
#      Average Rate of Agricultural land (% of land area)  \
# 0                                              11.1111
# 1                                              44.7390
# 2                                              58.1366
# 3                                              38.7831
# 4                                              42.0572
# ..                                                 ...
# 261                                                NaN
# ...

# %%
df_c = df_c.loc[:,~df_c.columns.duplicated()]
df_c
# Out:
#                           Entity Code  \
# 0                          Aruba  ABW
# 1    Africa Eastern and Southern  AFE
# 2                    Afghanistan  AFG
# 3     Africa Western and Central  AFW
# 4                         Angola  AGO
# ..                           ...  ...
# 261                       Kosovo  XKX
# 262                  Yemen, Rep.  YEM
# 263                 South Africa  ZAF
# 264                       Zambia  ZMB
# 265                     Zimbabwe  ZWE
#
#      Average Rate of Agricultural land (% of land area)  \
# 0                                              11.1111
# 1                                              44.7390
# 2                                              58.1366
# 3                                              38.7831
# 4                                              42.0572
# ..                                                 ...
# 261                                                NaN
# ...

# %%
df_c.isnull().sum()
# Out:
# Entity                                                       0
# Code                                                         0
# Average Rate of Agricultural land (% of land area)          10
# Average Rate Trend of Agricultural land (% of land area)    10
# Average Rate of Forest area (% of land area)                12
# Average Rate Trend of Forest area (% of land area)          12
# Average Rate of GDP per capita (current US$)                27
# Average Rate Trend of GDP per capita (current US$)          27
# dtype: int64

# %%
human_development = pd.read_csv('human-development-index-vs-corruption-perception-index.csv')

col_entity = human_development.Entity.unique()

human_development['Year'] = human_development['Year'].astype('int')
human_development.sort_values(by=['Year','Entity'], inplace=True)
human_development = human_development[human_development.Year >= 2000]

for entity in col_entity:
   
    data_mean = human_development[human_development.columns[3:5]][human_development.Entity == entity].mean()
    data_mean = pd.DataFrame(data_mean).T
    dict_ = data_mean.to_dict()
    dict_['Code'] = human_development[human_development.Entity == entity]['Code'].iloc[0]
    dict_['Entity'] = entity
    dict_
    data_mean_fix = pd.DataFrame(dict_)
    data_mean_fix = data_mean_fix[data_mean_fix.columns[::-1]]
    data_mean_fix

# %%
def get_mean(human_development, entity):
    data_mean = human_development[human_development.columns[3:5]][human_development.Entity == entity].mean()
    data_mean = pd.DataFrame(data_mean).T
    dict_ = data_mean.to_dict()
    dict_['Code'] = human_development[human_development.Entity == entity]['Code'].iloc[0]
    dict_['Entity'] = entity
    dict_
    data_mean_fix = pd.DataFrame(dict_)
    data_mean_fix = data_mean_fix[data_mean_fix.columns[::-1]]
    return data_mean_fix

# %%
human_development = pd.read_csv('human-development-index-vs-corruption-perception-index.csv')

col_entity = human_development.Entity.unique()

human_development['Year'] = human_development['Year'].astype('int')
human_development.sort_values(by=['Year','Entity'], inplace=True)
human_development = human_development[human_development.Year >= 2000]
data_mean_all = pd.DataFrame()

for entity in col_entity:
    data_mean_fix = get_mean(human_development, entity)
    data_mean_all = pd.concat([data_mean_all, data_mean_fix], axis=0)
data_mean_all
# Out:
#                    Entity      Code  \
# 0                Abkhazia  OWID_ABK
# 0             Afghanistan       AFG
# 0                  Africa       NaN
# 0   Akrotiri and Dhekelia  OWID_AKD
# 0                 Albania       ALB
# ..                    ...       ...
# 0              Yugoslavia  OWID_YGS
# 0                  Zambia       ZMB
# 0                Zanzibar  OWID_ZAN
# 0                Zimbabwe       ZWE
# 0           Åland Islands       ALA
#
#     Corruption Perception Index - Transparency International (2018)  \
# 0                                                 NaN
# 0                                           12.142857
# 0                                                 NaN
# 0                                                 NaN
# 0                                           35.142857
# ..                                                ...
# 0                                                 NaN
# 0                                           37.285714
# ...

# %%
data_mean_all.isnull().sum()
# Out:
# Entity                                                               0
# Code                                                                12
# Corruption Perception Index - Transparency International (2018)    118
# Human Development Index (UNDP)                                     108
# dtype: int64

# %%
data_prossed_worldbank = pd.merge(left=df_c, right=data_mean_all, on=['Entity','Code'], how='left')
data_prossed_worldbank.to_csv('data_prossed_worldbank.csv', index=False)

# %%
pd.read_csv('data_prossed_worldbank.csv')
# Out:
#                           Entity Code  \
# 0                          Aruba  ABW
# 1    Africa Eastern and Southern  AFE
# 2                    Afghanistan  AFG
# 3     Africa Western and Central  AFW
# 4                         Angola  AGO
# ..                           ...  ...
# 261                       Kosovo  XKX
# 262                  Yemen, Rep.  YEM
# 263                 South Africa  ZAF
# 264                       Zambia  ZMB
# 265                     Zimbabwe  ZWE
#
#      Average Rate of Agricultural land (% of land area)  \
# 0                                              11.1111
# 1                                              44.7390
# 2                                              58.1366
# 3                                              38.7831
# 4                                              42.0572
# ..                                                 ...
# 261                                                NaN
# ...

# %%
trend_energy = pd.read_csv('trend_energy.csv')
cols = trend_energy.columns
boundary = trend_energy[trend_energy.Entity == 'World'][cols[-1]].iloc[0]
def class_trend_energy(x, boundary):
    if x <= boundary:
        return 'good_trend'
    else:
        return 'bad_trend'
trend_energy['flag'] = trend_energy[cols[-1]].apply(lambda x: class_trend_energy(x, 0))
trend_energy
# Out:
#              Entity  Trend Fossil (% electricity)  \
# 0       Afghanistan                       -0.6718
# 1            Africa                       -0.1726
# 2           Albania                       -0.2089
# 3           Algeria                       -0.0670
# 4    American Samoa                        0.0000
# ..              ...                           ...
# 223  Western Sahara                       -0.0000
# 224           World                       -0.1537
# 225           Yemen                       -0.7762
# 226          Zambia                        0.6229
# 227        Zimbabwe                       -0.9948
#
#      Trend Renewable (% electricity)  \
# 0                             0.6718
# 1                             0.1689
# 2                             0.2089
# 3                             0.0382
# 4                             0.0000
# ..                               ...
# 223                           0.0000
# 224                           0.1477
# ...

# %%
dataset_for_suitable = pd.merge(left=trend_energy, right=data_prossed_worldbank, on='Entity', how='left')
dataset_for_suitable
# Out:
#              Entity  Trend Fossil (% electricity)  \
# 0       Afghanistan                       -0.6718
# 1            Africa                       -0.1726
# 2           Albania                       -0.2089
# 3           Algeria                       -0.0670
# 4    American Samoa                        0.0000
# ..              ...                           ...
# 223  Western Sahara                       -0.0000
# 224           World                       -0.1537
# 225           Yemen                       -0.7762
# 226          Zambia                        0.6229
# 227        Zimbabwe                       -0.9948
#
#      Trend Renewable (% electricity)  \
# 0                             0.6718
# 1                             0.1689
# 2                             0.2089
# 3                             0.0382
# 4                             0.0000
# ..                               ...
# 223                           0.0000
# 224                           0.1477
# ...

# %%
from scipy.spatial.distance import cdist

# %%
dataset_for_suitable.drop(columns='Code', inplace=True)

# %%
entity_1 = dataset_for_suitable[dataset_for_suitable.Entity == 'World'].drop(columns=['Entity','flag'])
entity_2 = dataset_for_suitable[dataset_for_suitable.Entity == 'Indonesia'].drop(columns=['Entity','flag'])

cols_nan_e1 = entity_1.columns[entity_1.isna().any()].tolist()
cols_nan_e2 = entity_2.columns[entity_2.isna().any()].tolist()
cols_nan = cols_nan_e1
cols_nan.extend(cols_nan_e2)

entity_1 = entity_1.drop(columns=cols_nan)
entity_2 = entity_2.drop(columns=cols_nan)

# %%
cdist(entity_1, entity_2, metric='cosine')
# Out:
# array([[0.00059468]])

# %%
option = 'Indonesia'

cols_country = dataset_for_suitable.Entity.unique()

dict_ = {}
col_entity = []
col_dist = []
for country in cols_country:
    if country == option:
        continue
        
    entity_1 = dataset_for_suitable[dataset_for_suitable.Entity == option].drop(columns=['Entity','flag'])
    entity_2 = dataset_for_suitable[dataset_for_suitable.Entity == country].drop(columns=['Entity','flag'])

    cols_nan_e1 = entity_1.columns[entity_1.isna().any()].tolist()
    cols_nan_e2 = entity_2.columns[entity_2.isna().any()].tolist()
    cols_nan = cols_nan_e1
    cols_nan.extend(cols_nan_e2)

    entity_1 = entity_1.drop(columns=cols_nan)
    entity_2 = entity_2.drop(columns=cols_nan)
    
    dist = cdist(entity_1, entity_2, metric='cosine')
    
    col_entity.append(country)
    col_dist.append(dist[0][0])

dict_['Entity'] = col_entity
dict_['Distance'] = col_dist

# %%
data_dist = pd.DataFrame(dict_)
data_dist = pd.merge(left=data_dist, right=dataset_for_suitable[['Entity','flag']], on='Entity', how='left')
data_dist[data_dist.flag == 'good_trend'].sort_values(by=['Distance']).reset_index(drop=True).head(5)
# Out:
#      Entity  Distance        flag
# 0    Guyana  0.000103  good_trend
# 1  Thailand  0.000103  good_trend
# 2   Albania  0.000106  good_trend
# 3   Belarus  0.000135  good_trend
# 4  Bulgaria  0.000146  good_trend

# %%
dataset_for_suitable[]
# Out:
#   Input In [205]
#     dataset_for_suitable[]
#                          ^
# SyntaxError: invalid syntax

# %%
df_[df_.Entity == 'Indonesia']
# Out:
#        Entity  Trend Fossil (% electricity)  Trend Renewable (% electricity)  \
# 96  Indonesia                       -0.0218                              0.0
#
#     Trend Carbon intensity of electricity (gCO2/kWh)
# 96                                            2.7056

# %%
elec_source[elec_source.Entity == 'Non-OECD (BP)']
# Out:
#              Entity Code  Year  Coal (% electricity)  Gas (% electricity)  \
# 4305  Non-OECD (BP)  NaN  1985             29.583460            24.346609
# 4306  Non-OECD (BP)  NaN  1986             30.403391            24.342438
# 4307  Non-OECD (BP)  NaN  1987             31.271883            23.799519
# 4308  Non-OECD (BP)  NaN  1988             31.079592            23.571928
# 4309  Non-OECD (BP)  NaN  1989             31.789408            23.803116
# 4310  Non-OECD (BP)  NaN  1990             32.008106            23.707224
# 4311  Non-OECD (BP)  NaN  1991             33.060135            23.022087
# 4312  Non-OECD (BP)  NaN  1992             34.571819            22.335196
# 4313  Non-OECD (BP)  NaN  1993             34.591858            21.819839
# 4314  Non-OECD (BP)  NaN  1994             36.382671            20.445606
# 4315  Non-OECD (BP)  NaN  1995             36.678448            20.100697
# 4316  Non-OECD (BP)  NaN  1996             37.497810            20.399153
# ...

# %%
np.nanmean([1,2,3,np.nan])
# Out:
# 2.0
